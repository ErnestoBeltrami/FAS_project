# %%
import sys
sys.path.append("..")
from src.parser import get_instructions
from src.analyzer import *
from src.plots import *

data_O0 = get_instructions("../temp/O0.txt")
data_O2 = get_instructions("../temp/O2.txt")

df_O0, sp_O0 = build_df(data_O0)
df_O2, sp_O2 = build_df(data_O2)

r_O0 = extract_rd_rs(data_O0)
r_O2 = extract_rd_rs(data_O2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.append("..")
#       3 from src.parser import get_instructions
# ----> 4 from src.analyzer import *
#       5 from src.plots import *
#       6
#       7 data_O0 = get_instructions("../temp/O0.txt")
#
# File ~/Documents/Scuola/Anno2/FAS/progetto/output/../src/analyzer.py:1
# ----> 1 import pandas as pd
#       3 def sp_tracker(data):
#       4     sp = 0
#
# ModuleNotFoundError: No module named 'pandas'

# %%
instruction_count(df_O0)
instruction_count(df_O2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 instruction_count(df_O0)
#       2 instruction_count(df_O2)
#
# NameError: name 'instruction_count' is not defined

# %%
sp_timeline(sp_O0,sp_O2)

# %%
category_pie(df_O0)
category_pie(df_O2)

# %%
registers_usage(r_O0)
registers_usage(r_O2)
