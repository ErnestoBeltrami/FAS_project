# %%
from parser import get_instructions
from analyzer import *
from instruction_type import *
registers = extract_rd_rs()

df,sp = build_df()

# %%
instruction_count(df)

# %%
sp_timeline(sp)

# %%
category_pie(df)

# %%
registers_usage(registers)
